# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv('data/NFLX.csv')
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2018-02-05  262.000000  267.899994  250.029999  254.259995  254.259995
# 1  2018-02-06  247.699997  266.700012  245.000000  265.720001  265.720001
# 2  2018-02-07  266.579987  272.450012  264.329987  264.559998  264.559998
# 3  2018-02-08  267.079987  267.619995  250.000000  250.100006  250.100006
# 4  2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001
#
#      Volume
# 0  11896100
# 1  12595800
# 2   8981500
# 3   9306700
# 4  16906900

# %%
X = df.drop(['Volume', 'Date'], axis=1)
Y = df['Volume']

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, random_state=25, shuffle=True)

# %%
regressor = LinearRegression()

# %%
regressor.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
regressor.score(x_test, y_test)
# Out:
# 0.41779347313107296

# %%
predicted = regressor.predict(x_test)

# %%
print(predicted)
# Out:
# [ 9731823.07196876 10922100.06386179 16799175.97372359  4032967.24439504
#   7615370.48676158 15410659.8976934   5264703.07712889  3562889.59547525
#   7587294.89263401  3234059.97863805  6913983.35563329  3239116.57431629
#   7546092.16998485  6665956.64395544 12629515.11689724  7187584.43973126
#   9830860.06852773 10217753.61253877  9704707.45947811  6054121.43121812
#  13030915.19858005 15459365.69572591  6659956.3821686   5896891.95655716
#   4366522.12739681  6347923.45691302 13814598.79323511  9536347.60564791
#   5303513.88706445  6801394.19090807 10277316.01557393 11363094.36711995
#  10758864.84907792  9190241.63422048  1353223.02221786  9989583.12707812
#   8785822.41781136  8126847.80923335  6419846.17427012  5908653.58955378
#   5983355.19680667  7316456.31732222 11824882.25067902  7229382.6707525
#   7768540.28085063  5791299.53127633  2850611.555886    6637893.42448703
#   3686123.18255188 11027420.06616978  6382621.29569057 11206597.85264186
# ...

# %%
df2 = pd.DataFrame({'Actual': y_test.values.flatten(), 'Predicted' : predicted.flatten()})

# %%
df2.head()
# Out:
#      Actual     Predicted
# 0  10429400  9.731823e+06
# 1  33866500  1.092210e+07
# 2  14402700  1.679918e+07
# 3   3887400  4.032967e+06
# 4   5667200  7.615370e+06
